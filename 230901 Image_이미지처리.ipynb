# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# 흑백 이미지로 로드

image = cv2.imread("Data/plane.jpg", cv2.IMREAD_GRAYSCALE)

# %%
# 이미지를 출력

plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()

# %%
# 이미지를 출력

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
# 데이터 타입을 확인

type(image)
# Out:
# numpy.ndarray

# %%
image   # pixel  0~255
# Out:
# array([[140, 136, 146, ..., 132, 139, 134],
#        [144, 136, 149, ..., 142, 124, 126],
#        [152, 139, 144, ..., 121, 127, 134],
#        ...,
#        [156, 146, 144, ..., 157, 154, 151],
#        [146, 150, 147, ..., 156, 158, 157],
#        [143, 138, 147, ..., 156, 157, 157]], dtype=uint8)

# %%
# 이미지 해상도(차원)
image.shape
# Out:
# (2270, 3600)

# %%
# 컬러로 이미지를 로드
image_bgr = cv2.imread("Data/plane.jpg", cv2.IMREAD_COLOR)
image_bgr.shape
# Out:
# (2270, 3600, 3)

# %%
image_bgr
# Out:
# array([[[195, 144, 111],
#         [191, 140, 107],
#         [201, 150, 117],
#         ...,
#         [187, 136, 103],
#         [194, 143, 110],
#         [189, 138, 105]],
#
#        [[199, 148, 115],
#         [191, 140, 107],
#         [204, 153, 120],
#         ...,
#         [197, 146, 113],
#         [179, 128,  95],
#         [181, 130,  97]],
#
#        [[207, 156, 123],
#         [194, 143, 110],
#         [199, 148, 115],
#         ...,
#         [176, 125,  92],
#         [182, 131,  98],
#         [189, 138, 105]],
#
#        ...,
#
#        [[211, 162, 124],
#         [201, 152, 114],
#         [201, 149, 112],
#         ...,
#         [189, 159, 140],
#         [186, 156, 137],
#         [183, 153, 134]],
#
#        [[201, 152, 114],
#         [205, 156, 118],
#         [202, 153, 115],
#         ...,
#         [188, 158, 139],
#         [190, 160, 141],
#         [187, 160, 140]],
#
#        [[200, 148, 111],
#         [195, 143, 106],
#         [204, 152, 115],
# ...

# %%
plt.imshow(image_bgr)
# opencv에서는 BGR color를 사용, matplotlib 은 RGB 사용
# matplotlib에서 출력하려면 변환해야 함: BGR을 RGB로 변환

# opencv: height, width, channel
# matplotlib: width, height, channel   채널: 흑백 1, 컬러 3

image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# 이미지를 출력
plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
# 이미지를 출력
plt.imshow(image_bgr)
plt.axis("off")
plt.show()

# %%
# 이미지 저장
cv2.imwrite('Data/result/plane_new.jpg', image)
# Out:
# True

# %%
# 이미지 크기 변경
# 이미지 사이즈를 조절하는 이유
# 1. 다양한 사이즈의 이미지를 데이터 분석에 사용하려면 사이즈를 통일해야 함
# 2. 이미지 크기를 줄여서 메모리 사용량을 줄일 수 있음
# 흑백 이미지로 로드

image = cv2.imread("Data/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)
image_50x50 = cv2.resize(image, (50, 50))
print(image_50x50.shape)

# 이미지출력
plt.imshow(image_50x50, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# (50, 50)

# %%
image = cv2.imread("Data/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)
image.shape
# Out:
# (256, 256)

# %%
image_10x10 = cv2.resize(image, (10, 10))
image_100x100 = cv2.resize(image, (100, 100))
print(image_10x10.shape)
print(image_100x100.shape)

# 이미지출력
plt.imshow(image_10x10, cmap='gray')
plt.axis('off')
plt.show()

plt.imshow(image_100x100, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# (10, 10)
# (100, 100)

# %%
# 이미지 자르기
# 흑백 이미지로 로드
image = cv2.imread('Data/plane_256x256.jpg', cv2.IMREAD_GRAYSCALE)

# 열의 처음 절반과 모든 행 선택
image_cropped = image[:,:128]    # 모든행, 열은 128에서 짤림

# 이미지 출력
plt.imshow(image_cropped, cmap='gray')
plt.show()

# %%
# 이미지 흐리게하기: 각 픽셀을 주변 픽셀의 평균값으로 변환
image = cv2.imread('Data/plane_256x256.jpg', cv2.IMREAD_GRAYSCALE)
# kernel_size 10X10 , 커널 사이즈가 클수록 이미지가 더 부드러워짐
image_blurry = cv2.blur(image, (10,10))
plt.imshow(image_blurry, cmap='gray'), plt.axis('off')
plt.show()

# %%
image_blurry = cv2.blur(image, (15,15))
plt.imshow(image_blurry, cmap='gray'), plt.axis('off')
plt.show()

# %%
image_blurry = cv2.blur(image, (3,3))
plt.imshow(image_blurry, cmap='gray'), plt.axis('off')
plt.show()

# %%
# kernel만들기
kernel = np.ones((5,5)) / 25.0

# kernel 값, 모두 더하면 1
print(sum(kernel.flatten())) 

# kernel확인
print(kernel)
# Out:
# 1.0000000000000002
# [[0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]]

# %%
# kernel 적용
# src : 이미지
# ddepth: 이미지 깊이(자료형 크기), -1이면 입력과 동일
# kernel: 커널 행렬

image_kernel = cv2.filter2D(image, -1, kernel)
print(image_kernel)

# 이미지 출력 
plt.imshow(image_kernel, cmap = 'gray')
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# [[137 138 138 ... 130 130 130]
#  [138 138 138 ... 130 130 130]
#  [137 137 138 ... 130 130 130]
#  ...
#  [151 151 152 ... 168 167 167]
#  [151 152 152 ... 167 167 167]
#  [151 152 153 ... 167 167 167]]

# %%
# 이미지를 선명하게 처리

image = cv2.imread('Data/plane_256x256.jpg', cv2.IMREAD_GRAYSCALE)


# 중앙 픽셀 부각
kernel = np.array([[0,-1,0], 
                   [-1,5,-1], 
                   [0,-1,0]])

# 이미지 선명하게
image_sharp = cv2.filter2D(image, -1, kernel)

# 이미지출력
plt.imshow(image_sharp, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
# 중앙 픽셀 부각
# kernel = np.array([[5,1,5], [1,0,1], [5,1,5]])
kernel = np.array([[0,1,0],
                   [1,0,1], 
                   [0,1,0]])

# 이미지 선명하게
image_sharp2 = cv2.filter2D(image, -1, kernel)

# 이미지출력
plt.imshow(image_sharp2, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
# 이미지 대비
image_enhanced = cv2.equalizeHist(image)   # 히스토그램 평탄화    0 black   ~   255 white

# 이미지를 출력
plt.imshow(image_enhanced, cmap="gray"), plt.axis("off")
plt.show()

# %%
plt.hist(image_enhanced)
plt.show()

# %%
plt.hist(image_sharp)
plt.show()

# %%
plt.hist(image.ravel(), 256, [0,256])
plt.axis('off')
plt.show()

# %%
plt.hist(image_sharp.ravel(), 256, [0,256])
plt.axis('off')
plt.show()

# %%
plt.hist(image_enhanced.ravel(), 256, [0,256])
plt.axis('off')
plt.show()

# %%
# 경계선 감지 : 경계선은 많은 정보가 담긴 영역
# 정보가 적은 영역을 제거하고 대부분의 정보가 담긴 이미지 영역을 구분할 수 있음

# 흑백 이미지로 로드
image_gray = image.copy()

# 픽셀 강도의 중간값을 계산
median_intensity = np.median(image_gray)
print( np.mean(image_gray), np.std(image_gray), np.median(image_gray) )
# Out:
# 124.40150451660156 45.91683477898078 132.0

# %%
image_gray = cv2.imread('Data/plane_256x256.jpg', cv2.IMREAD_GRAYSCALE)
median_intensity = np.median(image_gray)
print( np.mean(image_gray), np.std(image_gray), np.median(image_gray) )
# Out:
# 124.40150451660156 45.91683477898078 132.0

# %%
# 중간 픽셀 강도에서 위아래 1 표준편차 떨어진 값을 임계값으로 지정
lower_threshold = int(max(0, (1.0 - 0.33) * median_intensity))
upper_threshold = int(min(255, (1.0 + 0.33) * median_intensity))

# 경계선 감지 함수를 적용

image_canny = cv2.Canny(image_gray, lower_threshold, upper_threshold)

# 이미지를 출력
plt.imshow(image_canny, cmap="gray"), plt.axis("off")
plt.show()
