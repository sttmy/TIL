# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

params = {'legend.fontsize': 'medium',
          'figure.figsize': (8, 5),
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'medium',
         'ytick.labelsize':'medium',
         'lines.markersize': 20,
          'lines.linewidth': 3
         }

pylab.rcParams.update(params)

# %%
X_SCALE = 100

# %%
# 3차 실험

def get_y(x):
    xn = x/X_SCALE #추가
    return np.cos(xn) + (np.sin(xn*10)*0.3)

def get_direction(error, px, cx):
    x_dir = (((cx-px)>0)-0.5) * 2
    error_dir = -((error>0)-0.5) * 2
    gradient_dir = x_dir * error_dir
    return gradient_dir * X_SCALE

def get_error(cy, py):
    return cy-py

def set_title(epoch, direction, error, lr):
    title_str = 'epoch: %d\nDirection: %.2f, dError: %.2f, lr: %.2f'% (epoch, direction, error, lr)
    plt.title(title_str)

# %%
N = 100
x = np.linspace(0, np.pi*2, N)* X_SCALE
y = get_y(x)
p = np.random.randint(0, x.shape[0]-1)
cx = x[p]
cy = y[p]
global global_n
global_n = 0

# %%
print(x)
print(y)
print(p)
print(cx, cy)
# Out:
# [  0.           6.34665183  12.69330365  19.03995548  25.3866073
#   31.73325913  38.07991095  44.42656278  50.7732146   57.11986643
#   63.46651825  69.81317008  76.15982191  82.50647373  88.85312556
#   95.19977738 101.54642921 107.89308103 114.23973286 120.58638468
#  126.93303651 133.27968833 139.62634016 145.97299198 152.31964381
#  158.66629564 165.01294746 171.35959929 177.70625111 184.05290294
#  190.39955476 196.74620659 203.09285841 209.43951024 215.78616206
#  222.13281389 228.47946572 234.82611754 241.17276937 247.51942119
#  253.86607302 260.21272484 266.55937667 272.90602849 279.25268032
#  285.59933214 291.94598397 298.2926358  304.63928762 310.98593945
#  317.33259127 323.6792431  330.02589492 336.37254675 342.71919857
#  349.0658504  355.41250222 361.75915405 368.10580588 374.4524577
#  380.79910953 387.14576135 393.49241318 399.839065   406.18571683
#  412.53236865 418.87902048 425.2256723  431.57232413 437.91897595
#  444.26562778 450.61227961 456.95893143 463.30558326 469.65223508
#  475.99888691 482.34553873 488.69219056 495.03884238 501.38549421
#  507.73214603 514.07879786 520.42544969 526.77210151 533.11875334
#  539.46540516 545.81205699 552.15870881 558.50536064 564.85201246
#  571.19866429 577.54531611 583.89196794 590.23861977 596.58527159
#  602.93192342 609.27857524 615.62522707 621.97187889 628.31853072]
# [ 1.          1.17585906  1.27842549  1.26542894  1.13806666  0.94055274
#   0.74292024  0.61377389  0.59360502  0.67906129  0.82429743  0.95888073
#   1.01527751  0.9552157   0.78465588  0.5515401   0.32719477  0.17863034
#   0.14252541  0.2110272   0.33489811  0.44278264  0.4690905   0.37963633
#   0.18504987 -0.06326638 -0.29305821 -0.43926127 -0.46924268 -0.39541229
#  -0.27029259 -0.16596761 -0.14591507 -0.24019238 -0.4336409  -0.67170285
#  -0.88158561 -1.00053132 -1.00018208 -0.89755183 -0.74833219 -0.62513947
#  -0.58917525 -0.6663375  -0.83708658 -1.04401274 -1.21415834 -1.28740113
#  -1.23984471 -1.09310658 -0.90588651 -0.75109914 -0.68747665 -0.73670123
#  -0.87497321 -1.04229866 -1.16587941 -1.18849565 -1.09082735 -0.89902098
#  -0.67455436 -0.49034682 -0.40241845 -0.42813586 -0.53951653 -0.67419922
#  -0.75980762 -0.74221815 -0.60672264 -0.38384334 -0.13753534  0.05962934
#   0.15463159  0.13455829  0.03153445 -0.08988604 -0.15795993 -0.12179415
#   0.02873523  0.25894264  0.50274524  0.68830461  0.76591181  0.72725617
#   0.60857372  0.47644945  0.40180312  0.43219057  0.57320816  0.78624308
#   1.00344578  1.15409374  1.19207919  1.11381563  0.9595895   0.79783074
#   0.69842845  0.70548414  0.8201143   1.        ]
# 80
# 507.73214603471405 0.5027452424220112

# %%
# 국소 최적해 문제를 해결하기 위한 방안: rmsprop, Adagrad 등의 알고리즘

# %%
# 3차 실험
learning_rate = 0.5

current_direction = (np.random.rand() - 0.5) * 100
nx = cx + current_direction
ny = get_y(nx)

# %%
from IPython import display
error, lr = [], []
for i in range(20):
    px, py = cx, cy   # previous
    cx, cy = nx, ny   # current
    d_error = get_error(cy, py)

    # 학습률 조절
    if d_error<1.0:
        learning_rate = (learning_rate * 0.5)
        if learning_rate < 1e-3:
            break
    error.append(d_error)
    lr.append(learning_rate)
    
    current_direction = get_direction(d_error, px, cx)*learning_rate
    nx = cx + current_direction
    ny = get_y(nx)

    display.clear_output(wait=True)
    display.display(plt.gcf())
    plt.plot(x,y)
    plt.plot([px, cx], [py, cy], 'r.-', alpha=0.5)
    plt.plot(cx, cy, 'r.')
    plt.plot([cx, nx], [cy, ny], 'g-')
    plt.plot([cx, cx], [cy, cy])
    set_title((i+2), current_direction, d_error, learning_rate)
    plt.legend(['Error', 'Previous', 'Current', 'Next'])
    plt.show(block=False)
    plt.pause(0.5)
print('error:' , error)
print('lr:' , lr)
# Out:
# error: [-0.026051759810720054, 0.2952078860216846, -0.34254057373647595, -0.02707348811049687, 0.026600938571355814, -0.016307922035111333, -0.00593518789541847, -0.0023801580463402305]
# lr: [0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625, 0.001953125]

# %%
learning_rate = 3.0

current_direction = (np.random.rand() - 0.5) * 100
nx = cx + current_direction
ny = get_y(nx)

# %%
from IPython import display
error, lr = [], []
for i in range(20):
    px, py = cx, cy   # previous
    cx, cy = nx, ny   # current
    d_error = get_error(cy, py)

    # 학습률 조절
    if d_error<1.0:
        learning_rate = (learning_rate * 0.5)
        if learning_rate < 1e-3:
            break
    error.append(d_error)
    lr.append(learning_rate)
    
    current_direction = get_direction(d_error, px, cx)*learning_rate
    nx = cx + current_direction
    ny = get_y(nx)

    display.clear_output(wait=True)
    display.display(plt.gcf())
    plt.plot(x,y)
    plt.plot([px, cx], [py, cy], 'r.-', alpha=0.5)
    plt.plot(cx, cy, 'r.')
    plt.plot([cx, nx], [cy, ny], 'g-')
    plt.plot([cx, cx], [cy, cy])
    set_title((i+2), current_direction, d_error, learning_rate)
    plt.legend(['Error', 'Previous', 'Current', 'Next'])
    plt.show(block=False)
    plt.pause(0.5)
print('error:' , error)
print('lr:' , lr)
# Out:
# error: [0.3509120166017586, -0.15659473614348673, -0.3785073160174076, -0.27777347585098644, -0.41205563931560474, 0.12486762674952073, -0.08230376082183283, -0.027690966977576448, -0.009184818901869507, -0.003296896538467542, -0.0013106105537910029]
# lr: [1.5, 0.75, 0.375, 0.1875, 0.09375, 0.046875, 0.0234375, 0.01171875, 0.005859375, 0.0029296875, 0.00146484375]

# %%
learning_rate = 0.5 

current_direction = (np.random.rand() - 0.5) * 100
nx = cx + current_direction
ny = get_y(nx)

# %%
from IPython import display
error, lr = [], []
for i in range(20):
    px, py = cx, cy   # previous
    cx, cy = nx, ny   # current
    d_error = get_error(cy, py)
    error.append(d_error)
    current_direction = get_direction(d_error, px, cx)*learning_rate
    nx = cx + current_direction
    ny = get_y(nx)

    display.clear_output(wait=True)
    display.display(plt.gcf())
    plt.plot(x,y)
    plt.plot([px, cx], [py, cy], 'r.-', alpha=0.5)
    plt.plot(cx, cy, 'r.')
    plt.plot([cx, nx], [cy, ny], 'g-')
    plt.plot([cx, cx], [cy, cy])
    set_title((i+2), current_direction, d_error, learning_rate)
    plt.legend(['Error', 'Previous', 'Current', 'Next'])
    plt.show(block=False)
    plt.pause(0.5)
print('error:' , error)
# Out:
# error: [0.08971096243928334, 0.839717944334862, -0.839717944334862, -0.6204593805709535, -0.01999596057492159, 0.305519187191295, -0.305519187191295, 0.01999596057492159, -0.01999596057492159, 0.305519187191295, -0.305519187191295, 0.01999596057492159, -0.01999596057492159, 0.305519187191295, -0.305519187191295, 0.01999596057492159, -0.01999596057492159, 0.305519187191295, -0.305519187191295, 0.01999596057492159]
