# %%
import numpy as np
import matplotlib.pyplot as plt

def percent(x):
    return x / np.sum(x)

def softmax(x):
    exp_x = np.exp(x)
    return exp_x / np.sum(exp_x)

# %%
# value = np.linspace(-2.5, 2.5, 5)  # 무한대 문제 발생
# value = np.linspace(0, 2.5, 5)  # 출력값이 0이면 학습 안 됨
value = np.linspace(1.5, 2.5, 5)
p = percent(value)
s = softmax(value)
print('value: ', value)
print('percentage: ', p)
print('softmax: ', s)
# Out:
# value:  [1.5  1.75 2.   2.25 2.5 ]
# percentage:  [0.15  0.175 0.2   0.225 0.25 ]
# softmax:  [0.11405072 0.14644403 0.18803785 0.24144538 0.31002201]

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(value,'r.-',label='value')
plt.subplot(1,2,2)
plt.plot(p, 'b.-',label='percent')
plt.plot(s, 'g.-',label='softmax')
plt.legend()
plt.show()

# percent - 직선형태, 활성화함수로 사용하기 어려움
# sigmoid와 비슷한 형태
# 대소관계는 변하지 않고 큰 값은 더 크게, 작은 값은 더 작게 표현되도록 가중치를 조정함

# %%
value = np.linspace(0, 2.5, 5)  # 출력값이 0이면(0에 너무 가까우면) 학습 안 됨
# value = np.linspace(1.5, 2.5, 5)
p = percent(value)
s = softmax(value)
print('value: ', value)
print('percentage: ', p)
print('softmax: ', s)
# Out:
# value:  [0.    0.625 1.25  1.875 2.5  ]
# percentage:  [0.  0.1 0.2 0.3 0.4]
# softmax:  [0.0399012  0.07454526 0.13926888 0.26018852 0.48609615]

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(value,'r.-',label='value')
plt.subplot(1,2,2)
plt.plot(p, 'b.-',label='percent')
plt.plot(s, 'g.-',label='softmax')
plt.legend()
plt.show()

# percent - 직선형태, 활성화함수로 사용하기 어려움
# sigmoid와 비슷한 형태
# 대소관계는 변하지 않고 큰 값은 더 크게, 작은 값은 더 작게 표현되도록 가중치를 조정함

# %%
value = np.linspace(-2.5, 2.5, 5)  # 무한대 문제 발생
p = percent(value)
s = softmax(value)
print('value: ', value)
print('percentage: ', p)
print('softmax: ', s)
# Out:
# value:  [-2.5  -1.25  0.    1.25  2.5 ]
# percentage:  [-inf -inf  nan  inf  inf]
# softmax:  [0.00481679 0.01681225 0.05868053 0.20481518 0.71487524]
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_2324\3493031783.py:5: RuntimeWarning: divide by zero encountered in divide
#   return x / np.sum(x)
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_2324\3493031783.py:5: RuntimeWarning: invalid value encountered in divide
#   return x / np.sum(x)

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(value,'r.-',label='value')
plt.subplot(1,2,2)
plt.plot(p, 'b.-',label='percent')
plt.plot(s, 'g.-',label='softmax')
plt.legend()
plt.show()

# percent - 직선형태, 활성화함수로 사용하기 어려움

# sigmoid와 비슷한 형태

# 대소관계는 변하지 않고 큰 값은 더 크게, 작은 값은 더 작게 표현되도록 가중치를 조정함
